# %%
import os, cv2, PIL
import IPython.display
from syncWeights import sync_deepmating, sync_midas
import monodepth, deepmatting
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/emmanuel/my-code-projects/deep-bg-remover/env/bin/python -m pip install --upgrade pip' command.

# %%
sync_deepmating('weights')
sync_midas('weights')
# Out:
# downloading deepmatting, (108 MB)
# downloading MiDaS, (143 MB)

# %%
def imshow(img):
    import cv2
    import IPython
    _,ret = cv2.imencode('.jpg', img) 
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)
    
img = cv2.imread('go.png')
depth = monodepth.getMonoDepth(img, False)
matting = deepmatting.getnewalpha(img, depth, False)
imshow(matting[:,:,3])
# Out:
# (634, 1215, 4)
